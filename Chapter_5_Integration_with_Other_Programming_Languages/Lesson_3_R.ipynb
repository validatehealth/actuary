# %%
import pandas as pd

# Import from the rpy2 module
from rpy2 import robjects
from rpy2.robjects.packages import importr
from rpy2.robjects import pandas2ri

# %%
stats = importr('stats') # Needed to run a linear regression in R
base = importr('base') # Needed to output the summary of the linear regression

# %%
pandas2ri.activate() # Automatically convert pandas Data Frames to R Data Frames

# %%
df = pd.read_csv('files/all_claims_files.csv')

# %%
robjects.globalenv['df'] = df # Add the pandas Data Frame to the R environment

# %%
model = stats.lm('MEDREIMB_IP ~ BENE_ESRD_IND', data=base.as_symbol('df')) # Call the linear regression

# %%
base.summary(model) # output linear regression results
# Out:
# R object with classes: ('summary.lm',) mapped to:
# <ListVector - Python:0x10e644d48 / R:0x7fbc5ce9d200>
# [Vector, Formula, FloatVector, Matrix, ..., FloatVector, FloatVector, FloatVector, Matrix]
#   call: <class 'rpy2.robjects.vectors.Vector'>
#   R object with classes: ('lm',) mapped to:
# <Vector - Python:0x10e7cb748 / R:0x7fbc5cf5ec28>
# [SignatureTrans..., StrVector, RObject]
#   terms: <class 'rpy2.robjects.Formula'>
#   R object with classes: ('terms', 'formula') mapped to:
# <Formula - Python:0x10e63df88 / R:0x7fbc5cefb678>
#   residuals: <class 'rpy2.robjects.vectors.FloatVector'>
#   R object with classes: ('numeric',) mapped to:
# <FloatVector - Python:0x10e2a5a48 / R:0x7fbc5ef7f600>
# [-1459.599129, -1459.599129, -1459.599129, -1459.599129, ..., -1459.599129, -1459.599129, -1459.599129, -1459.599129]
#   coefficients: <class 'rpy2.robjects.vectors.Matrix'>
#   R object with classes: ('matrix',) mapped to:
# <Matrix - Python:0x10e639e08 / R:0x7fbc5d70d6f0>
# [1459.599129, 7116.581569, 101.693821, 356.948623, 14.352879, 19.937271, 0.000000, 0.000000]
# ...
#   sigma: <class 'rpy2.robjects.vectors.FloatVector'>
#   R object with classes: ('numeric',) mapped to:
# <FloatVector - Python:0x10e639508 / R:0x7fbc5d70ddd8>
# [0.062152]
#   df: <class 'rpy2.robjects.vectors.FloatVector'>
#   R object with classes: ('numeric',) mapped to:
# <FloatVector - Python:0x10e639608 / R:0x7fbc5d70dda8>
# [0.061996]
#   r.squared: <class 'rpy2.robjects.vectors.FloatVector'>
#   R object with classes: ('numeric',) mapped to:
# <FloatVector - Python:0x10e639348 / R:0x7fbc5e966ee0>
# [397.494791, 1.000000, 5998.000000]
#   adj.r.squared: <class 'rpy2.robjects.vectors.Matrix'>
#   R object with classes: ('matrix',) mapped to:
# <Matrix - Python:0x10e6392c8 / R:0x7fbc5e966e50>
# [0.000181, -0.000181, -0.000181, 0.002235]
